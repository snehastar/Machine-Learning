# %% [markdown]
# <a href="https://colab.research.google.com/github/snehastar/Machine-Learning/blob/main/Covid_19_exploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing the libraries

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
from IPython.core.display import display, HTML

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import folium
import plotly.graph_objects as go
import seaborn as sns
import ipywidgets as widgets

# %% [markdown]
# #Importing the dataset

# %%
death_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
recovered_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
country_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv')

# %% [markdown]
# #Viewing the data

# %%
confirmed_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  12/22/20  12/23/20  12/24/20
# 0            NaN    Afghanistan  33.93911  ...     50190     50433     50655
# 1            NaN        Albania  41.15330  ...     53814     54317     54827
# 2            NaN        Algeria  28.03390  ...     96069     96549     97007
# 3            NaN        Andorra  42.50630  ...      7633      7669      7699
# 4            NaN         Angola -11.20270  ...     16802     16931     17029
#
# [5 rows x 342 columns]

# %%
recovered_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  12/22/20  12/23/20  12/24/20
# 0            NaN    Afghanistan  33.93911  ...     39585     39692     40359
# 1            NaN        Albania  41.15330  ...     29249     29799     30276
# 2            NaN        Algeria  28.03390  ...     64020     64401     64777
# 3            NaN        Andorra  42.50630  ...      7073      7106      7171
# 4            NaN         Angola -11.20270  ...      9729      9729      9729
#
# [5 rows x 342 columns]

# %%
death_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  12/22/20  12/23/20  12/24/20
# 0            NaN    Afghanistan  33.93911  ...      2096      2117      2126
# 1            NaN        Albania  41.15330  ...      1111      1117      1125
# 2            NaN        Algeria  28.03390  ...      2687      2696      2705
# 3            NaN        Andorra  42.50630  ...        82        82        83
# 4            NaN         Angola -11.20270  ...       393       393       393
#
# [5 rows x 342 columns]

# %%
country_df.head()
# Out:
#   Country_Region          Last_Update       Lat  ...  Mortality_Rate  UID  ISO3
# 0    Afghanistan  2020-12-25 12:22:39  33.93911  ...        4.209801    4   AFG
# 1        Albania  2020-12-25 12:22:39  41.15330  ...        2.051909    8   ALB
# 2        Algeria  2020-12-25 12:22:39  28.03390  ...        2.788459   12   DZA
# 3        Andorra  2020-12-25 12:22:39  42.50630  ...        1.078062   20   AND
# 4         Angola  2020-12-25 12:22:39 -11.20270  ...        2.307828   24   AGO
#
# [5 rows x 14 columns]

# %% [markdown]
# #Data cleaning

# %% [markdown]
# Converting headings to lower case

# %%
country_df.columns = map(str.lower, country_df.columns)
death_df.columns = map(str.lower, death_df.columns)
confirmed_df.columns = map(str.lower, confirmed_df.columns)
recovered_df.columns = map(str.lower, recovered_df.columns)

# %%
country_df.isnull().sum()
# Out:
# country_region           0
# last_update              0
# lat                      2
# long_                    2
# confirmed                0
# deaths                   0
# recovered                4
# active                   0
# incident_rate            2
# people_tested          191
# people_hospitalized    191
# mortality_rate           0
# uid                      0
# iso3                     2
# dtype: int64

# %% [markdown]
# Renaming some of the columns

# %%
death_df = death_df.rename(columns = {'province/state' : 'state' , 'country/region' : 'country'})
confirmed_df = confirmed_df.rename(columns = {'province/state' : 'state' , 'country/region' : 'country'})
recovered_df = recovered_df.rename(columns = {'province/state' : 'state' , 'country/region' : 'country'})
country_df = country_df.rename(columns = {'country_region' : 'country'})

# %% [markdown]
# #Analyzing the data

# %% [markdown]
# Sorting the data on the basis of confirmed cases

# %%
sorted_country_df = country_df.sort_values('confirmed', ascending = False)
sorted_country_df.head()
# Out:
#     country          last_update        lat  ...  mortality_rate  uid  iso3
# 177      US  2020-12-25 12:22:39  40.000000  ...        1.764118  840   USA
# 79    India  2020-12-25 12:22:39  20.593684  ...        1.449633  356   IND
# 23   Brazil  2020-12-25 12:22:39 -14.235000  ...        2.559044   76   BRA
# 141  Russia  2020-12-25 12:22:39  61.524000  ...        1.788046  643   RUS
# 62   France  2020-12-25 12:22:39  46.227600  ...        2.413995  250   FRA
#
# [5 rows x 14 columns]

# %% [markdown]
# Highlighting the important columns

# %%
def highlight_col(x):
  p = 'background-color : pink'
  y = 'background-color : yellow'
  g = 'background-color : skyblue'
  temp_df = pd.DataFrame('', index = x.index, columns= x.columns)
  temp_df.iloc[: , 4] = p
  temp_df.iloc[: , 5] = y
  temp_df.iloc[: , 6] = g
  return temp_df
sorted_country_df.head(5).style.apply(highlight_col, axis = None)
# Out:
# <style  type="text/css" >
# #T_82c1d310_46b3_11eb_8756_0242ac1c0002row0_col4,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row1_col4,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row2_col4,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row3_col4,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row4_col4{
#             background-color :  pink;
#         }#T_82c1d310_46b3_11eb_8756_0242ac1c0002row0_col5,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row1_col5,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row2_col5,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row3_col5,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row4_col5{
#             background-color :  yellow;
#         }#T_82c1d310_46b3_11eb_8756_0242ac1c0002row0_col6,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row1_col6,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row2_col6,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row3_col6,#T_82c1d310_46b3_11eb_8756_0242ac1c0002row4_col6{
#             background-color :  skyblue;
# ...

# %% [markdown]
# #Visualize the data

# %%
fig = px.scatter(sorted_country_df.head(15) , x = 'country', y = 'confirmed', size = 'confirmed', color = 'country',
      hover_name = "country", size_max = 70)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b43bfda1-de21-4a34-a255-23db8988801c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b43bfda1-de21-4a34-a255-23db8988801c")) {
#                     Plotly.newPlot(
#                         'b43bfda1-de21-4a34-a255-23db8988801c',
# ...

# %%
def plot_cases_for_country(country):
  labels = ['confirmed' , 'deaths']
  colors = ['blue' , 'red']
  mode_size = [6,8]
  line_size = [4,5]
  df_list = [confirmed_df, death_df]
  fig = go.Figure()

  for i, df in enumerate(df_list):
    if country == 'World' or country == 'world':
      x_data = np.array(list(df.iloc[:,5:].columns))
      y_data = np.sum(np.array(df.iloc[: , 5:]), axis =0)
    else:
      x_data = np.array(list(df.iloc[:,5:].columns))
      y_data = np.sum(np.asarray(df[df['country']==country].iloc[: , 5:]), axis = 0)

    fig.add_trace(go.Scatter(x = x_data, y = y_data, mode = 'lines+markers',
                             name = labels[i], line = dict(color = colors[i],width = line_size[i]),
                             connectgaps = True, 
                             text = "Total" + str(labels[i]) + ": "+ str(y_data[-1])
                             ))
    fig.show()
#plot_cases_for_country('India')
interact(plot_cases_for_country, country = 'World')
# Out:
# interactive(children=(Text(value='World', description='country'), Output()), _dom_classes=('widget-interact',)…
# <function __main__.plot_cases_for_country>

# %%
df1 = confirmed_df.dropna(subset=['lat','long'], axis=0 )
df2 = death_df.dropna(subset=['lat','long'], axis=0 )
df1.head()
# Out:
#   state      country       lat  ...  12/22/20  12/23/20  12/24/20
# 0   NaN  Afghanistan  33.93911  ...     50190     50433     50655
# 1   NaN      Albania  41.15330  ...     53814     54317     54827
# 2   NaN      Algeria  28.03390  ...     96069     96549     97007
# 3   NaN      Andorra  42.50630  ...      7633      7669      7699
# 4   NaN       Angola -11.20270  ...     16802     16931     17029
#
# [5 rows x 342 columns]

# %%
df1.isnull().sum()
# Out:
# state       188
# country       0
# lat           0
# long          0
# 1/22/20       0
#            ...
# 12/20/20      0
# 12/21/20      0
# 12/22/20      0
# 12/23/20      0
# 12/24/20      0
# Length: 342, dtype: int64

# %%
world_map = folium.Map(location=[11,0],
   zoom_start=2, width = '100%', height='100%', position = 'relative',
   tiles='OpenStreetMap',
   max_zoom=4, min_zoom =2)

for i in range(0,len(df1)):
    folium.Circle(
        location=[df1.iloc[i]['lat'], df1.iloc[i]['long']],
        fill=True,
        radius=(int((np.log(df1.iloc[i,-1]+1.00001)))+0.2)*50000,
        color='red',
        fill_color='indigo',
        tooltip = "<div style='margin: 0; background-color: black; color: white;'>"+
                    "<h4 style='text-align:center;font-weight: bold'>"+df1.iloc[i]['country'] + "</h4>"
                    "<hr style='margin:10px;color: white;'>"+
                    "<ul style='color: white;;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px'>"+
                        "<li>Confirmed: "+str(df1.iloc[i,-1])+"</li>"+
                        "<li>Deaths:   "+str(df2.iloc[i,-1])+"</li>"+
                        "<li>Death Rate: "+ str(np.round(df2.iloc[i,-1]/(df1.iloc[i,-1]+1.00001)*100,2))+ "</li>"+
                    "</ul></div>",
        ).add_to(world_map)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
